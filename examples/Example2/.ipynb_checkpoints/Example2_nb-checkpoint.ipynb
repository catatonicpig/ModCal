# %% [markdown]
# ## Bayesian Calibration: Acceleration due to Gravity

# %% [markdown]
# To illustrate how to use XXX within YYY we will start with a very simple example of a falling ball example.
#
# First, import the main libraries we use for this example:

# %%
import numpy as np
from scipy.stats import norm
from pyDOE import *
import scipy.optimize as spo
import sys
import os
from matplotlib import pyplot as plt
import scipy.stats as sps

# %% [markdown]
# ### Data: Acceleration due to Gravity

# %% [markdown]
# Let's read the real data first, and then visualize:

# %%
ball = np.loadtxt('ball.csv', delimiter=',')
n = len(ball)
#height
X = np.reshape(ball[:, 0], (n, 1))
X = X[0:21]
#time
Y = np.reshape(ball[:, 1], ((n, 1)))
# This is a stochastic one but we convert it deterministic by taking the average height
Ysplit = np.split(Y, 3)
ysum = 0
for y in  Ysplit:
    ysum += y 
obsvar = np.maximum(0.2*X, 0.5)
Y = ysum/3

# %%
plt.scatter(X, Y)
plt.xlabel("height")
plt.ylabel("time")
plt.show()

# %% [markdown]
# ### Computer model experiments

# %% [markdown]
# We know that $t = \sqrt{2h/g}$.

# %%
# Computer implementation of the mathematical model
def timedrop(x, theta, hr, gr):
    min_g = min(gr)
    range_g = max(gr) - min(gr)
    min_h = min(hr)
    range_h = max(hr) - min(hr)
    f = np.zeros((theta.shape[0], x.shape[0]))
    for k in range(0, theta.shape[0]):
        g = range_g*theta[k] + min_g
        h = range_h*x + min(hr)
        f[k, :] = np.sqrt(2*h/g).reshape(x.shape[0])
    return f.T

# %% [markdown]
# Consider computer model emulator where $u \in [0, 30]$:

# %%
# Draw 100 random parameters from uniform prior
n2 = 100
theta = lhs(1, samples=n2)
theta_range = np.array([1, 30])

# Standardize 
height_range = np.array([min(X), max(X)])
X_std = (X[0:21] - min(X))/(max(X) - min(X))

# Obtain computer model output
Y_model = timedrop(X_std, theta, height_range, theta_range)

print(np.shape(theta))
print(np.shape(X_std))
print(np.shape(Y_model))
# Out:
# (100, 1)
# (21, 1)
# (21, 100)

# %%
plt.plot(X, Y_model)
plt.xlabel("height")
plt.ylabel("time (model)")
plt.show()

# %% [markdown]
# ### Building an emulator via PCGPwM

# %%
current = os.path.abspath(os.getcwd())
sys.path.append(os.path.normpath(os.path.join(os.path.dirname(current), '..')))
from base.emulation import emulator

# %% [markdown]
# #### Emulator without filtering

# %%
emulator_no_f = emulator(X_std, theta, Y_model, method = 'PCGPwM')

# %% [markdown]
# Let's observe the quality of an emulator without filtering:

# %%
#Predict
pred_model = emulator_no_f.predict(X_std, theta)
pred_mean = pred_model.mean()
print(np.shape(pred_mean))
# Out:
# (21, 100)

# %%
for i in range(np.shape(pred_mean)[1]):
    plt.plot(X[0:21], pred_mean[:, i])
plt.xlabel("height")
plt.ylabel("time (emulator)")
plt.show()

# %% [markdown]
# #### Emulator with filtering

# %%
# Filter out the data
ys = 1 - np.sum((Y_model - Y)**2, 0)/np.sum((Y - np.mean(Y))**2, 0)
theta_f = theta[ys > 0.5]
print(theta_f.shape)
# Out:
# (33, 1)

# %%
# Obtain computer model output via filtered data
Y_model = timedrop(X_std, theta_f, height_range, theta_range)
print(np.shape(Y_model))
plt.plot(X, Y_model)
plt.xlabel("height")
plt.ylabel("time (model with filtered data)")
plt.show()
# Out:
# (21, 33)

# %%
# Fit an emulator via filtered data
emulator_f = emulator(X_std, theta_f, Y_model, method = 'PCGPwM')
pred_model = emulator_f.predict(X_std, theta_f)
pred_mean = pred_model.mean()
print(np.shape(pred_mean))
# Out:
# (21, 33)

# %%
for i in range(np.shape(pred_mean)[1]):
    plt.plot(X, pred_mean[:, i])
plt.xlabel("height")
plt.ylabel("time (emulator with filtered data)")
plt.show()

# %%
#Generate random reasonable theta values
theta_test = lhs(1, samples=1000)
theta_test = theta_test[(theta_test > 0.2) & (theta_test < 0.5)]
theta_test = theta_test.reshape(len(theta_test), 1)
theta_range = np.array([1, 30])
print(np.shape(theta_test))

# Obtain computer model output
Y_model_test = timedrop(X_std, theta_test, height_range, theta_range)
print(np.shape(Y_model_test))

#Predict
p_no_f = emulator_no_f.predict(X_std, theta_test)
pred_mean_no_f = p_no_f.mean()
p_f = emulator_f.predict(X_std, theta_test)
pred_mean_f = p_f.mean()
print(np.shape(pred_mean_no_f))
print(np.shape(pred_mean_f))
# Out:
# (300, 1)
# (21, 300)
# (21, 300)
# (21, 300)

# %%
np.sum((pred_mean_no_f - Y_model_test)**2)
# Out:
# 1.6761914329419693e-09

# %%
np.sum((pred_mean_f - Y_model_test)**2)
# Out:
# 3.7823290566167066e-06

# %% [markdown]
# ### Fitting a classifier

# %%
# Fit a classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
Y_cls = np.zeros(len(theta))
Y_cls[ys > 0.5] = 1
clf = RandomForestClassifier(n_estimators = 100, random_state = 42)#
clf.fit(theta, Y_cls)
print(clf.score(theta, Y_cls))
print(confusion_matrix(Y_cls, clf.predict(theta)))
# Out:
# 1.0
# [[67  0]
#  [ 0 33]]

# %% [markdown]
# ### Building a calibrator

# %% [markdown]
# ### Define the prior distribution

# %%
class prior_balldrop:
    """ This defines the class instance of priors provided to the method. """
    def lpdf(theta):
        return np.squeeze(sps.uniform.logpdf(theta, 0.1, 0.9))

    def rnd(n):
        return np.vstack((sps.uniform.rvs(0.1, 0.9, size=n)))

# %%
from base.calibration import calibrator

# %%
cal_f = calibrator(emulator_f, Y, X_std, thetaprior = prior_balldrop, method = 'MLcal', yvar = obsvar, args = {'clf_method': None})
cal_nf = calibrator(emulator_no_f, Y, X_std, thetaprior = prior_balldrop, method = 'MLcal', yvar = obsvar, args = {'clf_method': None}) 
cal_f_ml = calibrator(emulator_f, Y, X_std, thetaprior = prior_balldrop, method = 'MLcal', yvar = obsvar, args = {'clf_method': clf}) 
cal_nf_ml = calibrator(emulator_no_f, Y, X_std, thetaprior = prior_balldrop, method = 'MLcal', yvar = obsvar, args = {'clf_method': clf})
# Out:
# theta [[0.4]]
# prior 0.10536051565782628
# theta [[1.72118749]]
# prior -inf
# theta [[0.30997019]]
# prior 0.10536051565782628
# 1
# theta [[-0.27279371]]
# prior -inf
# theta [[-0.98534492]]
# prior -inf
# theta [[0.23598532]]
# prior 0.10536051565782628
# 1
# theta [[0.78386268]]
# prior 0.10536051565782628
# 0.990494603157143
# theta [[0.82641636]]
# prior 0.10536051565782628
# 0.9959276365259455
# theta [[2.0820892]]
# prior -inf
# theta [[1.81115641]]
# prior -inf
# theta [[0.64266906]]
# prior 0.10536051565782628
# 1
# theta [[1.50634178]]
# prior -inf
# theta [[0.02162256]]
# prior -inf
# theta [[0.94211626]]
# prior 0.10536051565782628
# 0.9733339432773827
# theta [[-1.07475198]]
# prior -inf
# theta [[-0.59179198]]
# prior -inf
# theta [[1.38356235]]
# prior -inf
# theta [[-0.0461138]]
# prior -inf
# theta [[-1.14821575]]
# prior -inf
# theta [[1.20189954]]
# prior -inf
# theta [[0.04496751]]
# prior -inf
# theta [[-0.36241196]]
# prior -inf
# theta [[1.59593364]]
# prior -inf
# theta [[-0.04354997]]
# prior -inf
# theta [[0.40243121]]
# prior 0.10536051565782628
# 1
# theta [[0.61063804]]
# prior 0.10536051565782628
# 0.9990628888608818
# theta [[0.28579331]]
# prior 0.10536051565782628
# 1
# theta [[0.22136058]]
# prior 0.10536051565782628
# 0.9999992624128323
# theta [[1.56202991]]
# prior -inf
# theta [[0.34022378]]
# prior 0.10536051565782628
# 0.9999875002565439
# theta [[0.50357041]]
# prior 0.10536051565782628
# 0.9999245896285073
# theta [[-0.00894132]]
# prior -inf
# theta [[0.79577911]]
# prior 0.10536051565782628
# 0.9895362803277807
# theta [[0.21560963]]
# prior 0.10536051565782628
# 1
# theta [[1.31688538]]
# prior -inf
# theta [[1.52825759]]
# prior -inf
# theta [[0.40868508]]
# prior 0.10536051565782628
# 0.9999656848842894
# theta [[-0.11688581]]
# prior -inf
# theta [[0.03788968]]
# prior -inf
# theta [[0.24370691]]
# prior 0.10536051565782628
# 1
# theta [[-0.46437688]]
# prior -inf
# theta [[1.42092587]]
# prior -inf
# theta [[-1.13201322]]
# prior -inf
# theta [[0.56900871]]
# prior 0.10536051565782628
# 0.9995966751862668
# theta [[-0.76304186]]
# prior -inf
# theta [[-0.04512709]]
# prior -inf
# theta [[0.86981859]]
# prior 0.10536051565782628
# 0.981926832820045
# theta [[1.02253261]]
# prior -inf
# theta [[0.09327146]]
# prior -inf
# theta [[1.5647021]]
# prior -inf
# theta [[1.32357935]]
# prior -inf
# theta [[1.16909339]]
# prior -inf
# theta [[-0.1886312]]
# prior -inf
# theta [[0.39554209]]
# prior 0.10536051565782628
# 1
# theta [[0.24131648]]
# prior 0.10536051565782628
# 1
# theta [[-0.20993027]]
# prior -inf
# theta [[0.29652318]]
# prior 0.10536051565782628
# 0.9999955273223337
# theta [[0.32891774]]
# prior 0.10536051565782628
# 0.9999920377900913
# theta [[1.22595868]]
# prior -inf
# theta [[-0.77658706]]
# prior -inf
# theta [[-0.01378414]]
# prior -inf
# theta [[-0.22240155]]
# prior -inf
# theta [[0.59363769]]
# prior 0.10536051565782628
# 0.9993189631189986
# theta [[0.38676919]]
# prior 0.10536051565782628
# 1
# theta [[1.07323021]]
# prior -inf
# theta [[0.23714955]]
# prior 0.10536051565782628
# 1
# theta [[0.85125971]]
# prior 0.10536051565782628
# 0.9837371357204898
# theta [[-0.80070194]]
# prior -inf
# theta [[1.14580964]]
# prior -inf
# theta [[0.46602054]]
# prior 0.10536051565782628
# 1
# theta [[1.72521692]]
# prior -inf
# theta [[0.68780552]]
# prior 0.10536051565782628
# 0.996724398392776
# theta [[-0.13025901]]
# prior -inf
# theta [[-0.36754854]]
# prior -inf
# theta [[-0.40764778]]
# prior -inf
# theta [[1.4235388]]
# prior -inf
# theta [[-0.79910749]]
# prior -inf
# theta [[1.4781593]]
# prior -inf
# theta [[0.64320463]]
# prior 0.10536051565782628
# 1
# theta [[0.10676357]]
# prior 0.10536051565782628
# 1
# theta [[0.86384027]]
# prior 0.10536051565782628
# 0.9824344023301301
# theta [[1.63365948]]
# prior -inf
# theta [[0.28304333]]
# prior 0.10536051565782628
# 1
# theta [[0.15755998]]
# prior 0.10536051565782628
# 0.9999507695716199
# theta [[0.05013433]]
# prior -inf
# theta [[0.47224377]]
# prior 0.10536051565782628
# 0.9999878061323789
# theta [[1.08426738]]
# prior -inf
# theta [[-0.62054475]]
# prior -inf
# theta [[1.1272359]]
# prior -inf
# theta [[0.4000769]]
# prior 0.10536051565782628
# 1
# theta [[0.75388139]]
# prior 0.10536051565782628
# 0.9928852999273884
# theta [[0.61541639]]
# prior 0.10536051565782628
# 1
# theta [[0.90180895]]
# prior 0.10536051565782628
# 0.9784458557321575
# theta [[2.21438792]]
# prior -inf
# theta [[-0.03377761]]
# prior -inf
# theta [[1.65246691]]
# prior -inf
# theta [[1.70929207]]
# prior -inf
# theta [[2.38432382]]
# prior -inf
# theta [[1.63764212]]
# prior -inf
# theta [[0.28674585]]
# prior 0.10536051565782628
# 1
# theta [[0.60804298]]
# prior 0.10536051565782628
# 0.9990762035489664
# theta [[0.00919167]]
# prior -inf
# theta [[0.15405401]]
# prior 0.10536051565782628
# 1
# theta [[0.23646224]]
# prior 0.10536051565782628
# 1
# theta [[-1.56976202]]
# prior -inf
# theta [[-0.65250072]]
# prior -inf
# theta [[2.28813144]]
# prior -inf
# theta [[0.43326602]]
# prior 0.10536051565782628
# 0.999952064892378
# theta [[-0.36465587]]
# prior -inf
# theta [[0.08278687]]
# prior -inf
# theta [[0.5984397]]
# prior 0.10536051565782628
# 0.9992828681268403
# theta [[-0.01907127]]
# prior -inf
# theta [[-0.47621131]]
# prior -inf
# theta [[1.30612502]]
# prior -inf
# theta [[1.03842746]]
# prior -inf
# theta [[0.3822208]]
# prior 0.10536051565782628
# 1
# theta [[0.49285525]]
# prior 0.10536051565782628
# 0.9999520722679991
# theta [[0.26616734]]
# prior 0.10536051565782628
# 1
# theta [[0.58846143]]
# prior 0.10536051565782628
# 0.9993783234915514
# theta [[1.63514047]]
# prior -inf
# theta [[1.20037031]]
# prior -inf
# theta [[-0.85418603]]
# prior -inf
# theta [[1.26430165]]
# prior -inf
# theta [[1.16893946]]
# prior -inf
# theta [[0.11927237]]
# prior 0.10536051565782628
# 1
# theta [[-0.96010505]]
# prior -inf
# theta [[0.19309091]]
# prior 0.10536051565782628
# 1
# theta [[-0.09084586]]
# prior -inf
# theta [[-0.47877738]]
# prior -inf
# theta [[-0.84900517]]
# prior -inf
# theta [[0.8637335]]
# prior 0.10536051565782628
# 0.9822850942654097
# theta [[0.42961644]]
# prior 0.10536051565782628
# 1
# theta [[1.12417363]]
# prior -inf
# theta [[0.36967299]]
# prior 0.10536051565782628
# 1
# theta [[-0.41819475]]
# prior -inf
# theta [[-0.77995453]]
# prior -inf
# theta [[-1.12387705]]
# prior -inf
# theta [[0.46976154]]
# prior 0.10536051565782628
# 0.9999628795683556
# theta [[0.79834331]]
# prior 0.10536051565782628
# 0.9892739845724074
# theta [[0.50848912]]
# prior 0.10536051565782628
# 1
# theta [[1.48780915]]
# prior -inf
# theta [[0.50921869]]
# prior 0.10536051565782628
# 0.999998621759817
# theta [[0.75934751]]
# prior 0.10536051565782628
# 0.9925501136560412
# theta [[0.38004426]]
# prior 0.10536051565782628
# 1
# theta [[-0.64695976]]
# prior -inf
# theta [[1.45965957]]
# prior -inf
# theta [[0.88036206]]
# prior 0.10536051565782628
# 0.98024317872867
# theta [[3.64032302]]
# prior -inf
# theta [[0.2516938]]
# prior 0.10536051565782628
# 1
# theta [[-0.06218359]]
# prior -inf
# theta [[0.25326784]]
# prior 0.10536051565782628
# 1
# theta [[1.63719469]]
# prior -inf
# theta [[1.12937644]]
# prior -inf
# theta [[0.00865004]]
# prior -inf
# theta [[-0.74829617]]
# prior -inf
# theta [[-1.12397773]]
# prior -inf
# theta [[0.6532277]]
# prior 0.10536051565782628
# 0.9979675569344322
# theta [[1.01523657]]
# prior -inf
# theta [[0.75662482]]
# prior 0.10536051565782628
# 0.9946718077358969
# theta [[0.7193968]]
# prior 0.10536051565782628
# 1
# theta [[0.74006732]]
# prior 0.10536051565782628
# 0.9987252096633039
# theta [[0.57964307]]
# prior 0.10536051565782628
# 1
# theta [[1.31480457]]
# prior -inf
# theta [[0.84665497]]
# prior 0.10536051565782628
# 0.9847669964314392
# theta [[0.24337289]]
# prior 0.10536051565782628
# 1
# theta [[0.09028336]]
# prior -inf
# theta [[1.1679658]]
# prior -inf
# theta [[0.20002126]]
# prior 0.10536051565782628
# 0.999988451242136
# theta [[-0.73765666]]
# prior -inf
# theta [[0.49844284]]
# prior 0.10536051565782628
# 0.9999274705616631
# theta [[-0.46621528]]
# prior -inf
# theta [[1.22130366]]
# prior -inf
# theta [[1.15229612]]
# prior -inf
# theta [[-0.36548682]]
# prior -inf
# theta [[1.1091328]]
# prior -inf
# theta [[0.57131117]]
# prior 0.10536051565782628
# 0.9996587586087339
# theta [[0.63380327]]
# prior 0.10536051565782628
# 0.9989436886889778
# theta [[0.39255143]]
# prior 0.10536051565782628
# 1
# theta [[0.21704652]]
# prior 0.10536051565782628
# 1
# theta [[-0.29300012]]
# prior -inf
# theta [[-0.93503243]]
# prior -inf
# theta [[0.46067711]]
# prior 0.10536051565782628
# 0.9999456115597851
# theta [[-0.13339255]]
# prior -inf
# theta [[-0.71683357]]
# prior -inf
# theta [[-0.63833169]]
# prior -inf
# theta [[1.7923763]]
# prior -inf
# theta [[-0.32344778]]
# prior -inf
# theta [[-0.50212258]]
# prior -inf
# theta [[0.24897551]]
# prior 0.10536051565782628
# 1
# theta [[1.62548596]]
# prior -inf
# theta [[1.11015914]]
# prior -inf
# theta [[-0.56403933]]
# prior -inf
# theta [[2.32599819]]
# prior -inf
# theta [[-1.46683021]]
# prior -inf
# theta [[-0.6983667]]
# prior -inf
# theta [[0.16474192]]
# prior 0.10536051565782628
# 0.9999581317927794
# theta [[0.38267557]]
# prior 0.10536051565782628
# 1
# theta [[1.41106821]]
# prior -inf
# theta [[-0.21778035]]
# prior -inf
# theta [[1.63583775]]
# prior -inf
# theta [[-0.20656626]]
# prior -inf
# theta [[-0.42131491]]
# prior -inf
# theta [[-0.64417155]]
# prior -inf
# theta [[0.68199007]]
# prior 0.10536051565782628
# 0.9969437345096676
# theta [[-0.53032712]]
# prior -inf
# theta [[-1.27513769]]
# prior -inf
# theta [[0.11756945]]
# prior 0.10536051565782628
# 1
# theta [[1.77456832]]
# prior -inf
# theta [[1.15568148]]
# prior -inf
# theta [[0.67702484]]
# prior 0.10536051565782628
# 0.9972553195621308
# theta [[0.59812457]]
# prior 0.10536051565782628
# 1
# theta [[-0.30883858]]
# prior -inf
# theta [[0.50978874]]
# prior 0.10536051565782628
# 1
# theta [[1.6324316]]
# prior -inf
# theta [[1.44835774]]
# prior -inf
# theta [[0.68574813]]
# prior 0.10536051565782628
# 0.9968554516882778
# theta [[2.11444034]]
# prior -inf
# theta [[0.4144721]]
# prior 0.10536051565782628
# 1
# theta [[1.67393106]]
# prior -inf
# theta [[0.12112818]]
# prior 0.10536051565782628
# 0.9999143836287979
# theta [[-0.9413617]]
# prior -inf
# theta [[1.06890696]]
# prior -inf
# theta [[0.11796538]]
# prior 0.10536051565782628
# 0.9999901123500806
# theta [[0.33557512]]
# prior 0.10536051565782628
# 1
# theta [[0.28723164]]
# prior 0.10536051565782628
# 1
# theta [[2.30088054]]
# prior -inf
# theta [[1.58177648]]
# prior -inf
# theta [[0.12221384]]
# prior 0.10536051565782628
# 0.9998789725666701
# theta [[0.66248307]]
# prior 0.10536051565782628
# 0.9977846729560834
# theta [[1.01598007]]
# prior -inf
# theta [[0.54189766]]
# prior 0.10536051565782628
# 1
# theta [[-0.00432875]]
# prior -inf
# theta [[-0.64553032]]
# prior -inf
# theta [[0.5794428]]
# prior 0.10536051565782628
# 0.9996995228187179
# theta [[0.77679459]]
# prior 0.10536051565782628
# 0.9915921856353136
# theta [[-0.10124278]]
# prior -inf
# theta [[0.88478926]]
# prior 0.10536051565782628
# 0.9884605381306114
# theta [[2.80027261]]
# prior -inf
# theta [[0.67134313]]
# prior 0.10536051565782628
# 1
# theta [[-0.09703543]]
# prior -inf
# theta [[-0.28438422]]
# prior -inf
# theta [[1.09033796]]
# prior -inf
# theta [[0.90671205]]
# prior 0.10536051565782628
# 0.9793410611643313
# theta [[1.64533471]]
# prior -inf
# theta [[1.12617066]]
# prior -inf
# theta [[1.10466506]]
# prior -inf
# theta [[3.3553229]]
# prior -inf
# theta [[0.48755345]]
# prior 0.10536051565782628
# 1
# theta [[0.6141898]]
# prior 0.10536051565782628
# 0.9990307496706377
# theta [[0.46484847]]
# prior 0.10536051565782628
# 1
# theta [[1.44833154]]
# prior -inf
# theta [[0.43461991]]
# prior 0.10536051565782628
# 1
# theta [[1.22214517]]
# prior -inf
# theta [[-0.01702909]]
# prior -inf
# theta [[0.79897483]]
# prior 0.10536051565782628
# 0.9892025899914022
# theta [[0.57547068]]
# prior 0.10536051565782628
# 1
# theta [[1.81646825]]
# prior -inf
# theta [[0.73328971]]
# prior 0.10536051565782628
# 0.9947016108813893
# theta [[0.71885077]]
# prior 0.10536051565782628
# 1
# theta [[-0.70623978]]
# prior -inf
# theta [[1.80997135]]
# prior -inf
# theta [[0.90189827]]
# prior 0.10536051565782628
# 0.9822032646956803
# theta [[1.87614849]]
# prior -inf
# theta [[1.31882802]]
# prior -inf
# theta [[-0.75660678]]
# prior -inf
# theta [[1.34687441]]
# prior -inf
# theta [[0.42574256]]
# prior 0.10536051565782628
# 1
# theta [[0.46739663]]
# prior 0.10536051565782628
# 0.9999841390325794
# theta [[1.44337016]]
# prior -inf
# theta [[-0.68574436]]
# prior -inf
# theta [[0.1731461]]
# prior 0.10536051565782628
# 1
# theta [[-0.03488807]]
# prior -inf
# theta [[0.70883]]
# prior 0.10536051565782628
# 0.9956793944128494
# theta [[0.95384475]]
# prior 0.10536051565782628
# 0.9741301433230208
# theta [[1.96630033]]
# prior -inf
# theta [[-0.01907563]]
# prior -inf
# theta [[1.21924015]]
# prior -inf
# theta [[0.02090141]]
# prior -inf
# theta [[0.48427268]]
# prior 0.10536051565782628
# 1
# theta [[0.13855444]]
# prior 0.10536051565782628
# 0.9999857014592373
# theta [[1.25685883]]
# prior -inf
# theta [[0.33466127]]
# prior 0.10536051565782628
# 1
# theta [[-1.36891963]]
# prior -inf
# theta [[1.04556618]]
# prior -inf
# theta [[0.76964809]]
# prior 0.10536051565782628
# 0.9916748554362113
# theta [[1.51351915]]
# prior -inf
# theta [[0.81452633]]
# prior 0.10536051565782628
# 0.995974204510288
# theta [[0.26903083]]
# prior 0.10536051565782628
# 1
# theta [[0.13856927]]
# prior 0.10536051565782628
# 0.9999158038216603
# theta [[1.34659111]]
# prior -inf
# theta [[-0.55030693]]
# prior -inf
# theta [[0.73585364]]
# prior 0.10536051565782628
# 0.9941580900250292
# theta [[2.78625404]]
# prior -inf
# theta [[-0.21319981]]
# prior -inf
# theta [[1.92435537]]
# prior -inf
# theta [[-0.04584871]]
# prior -inf
# theta [[1.13621005]]
# prior -inf
# theta [[0.60582589]]
# prior 0.10536051565782628
# 1
# theta [[1.67106114]]
# prior -inf
# theta [[1.21256016]]
# prior -inf
# theta [[-1.00644931]]
# prior -inf
# theta [[1.09465986]]
# prior -inf
# theta [[1.64798675]]
# prior -inf
# theta [[-0.55149904]]
# prior -inf
# theta [[1.50441317]]
# prior -inf
# theta [[0.90551251]]
# prior 0.10536051565782628
# 0.9777667900356063
# theta [[0.98697153]]
# prior 0.10536051565782628
# 0.9874811004419382
# theta [[2.26986341]]
# prior -inf
# theta [[1.27500523]]
# prior -inf
# theta [[0.44507849]]
# prior 0.10536051565782628
# 1
# theta [[0.96906044]]
# prior 0.10536051565782628
# 0.9675812774838095
# theta [[-0.15238878]]
# prior -inf
# theta [[1.19800425]]
# prior -inf
# theta [[-0.03701846]]
# prior -inf
# theta [[0.61264937]]
# prior 0.10536051565782628
# 1
# theta [[1.43122778]]
# prior -inf
# theta [[1.60820342]]
# prior -inf
# theta [[-0.26060378]]
# prior -inf
# theta [[2.05809119]]
# prior -inf
# theta [[0.04130095]]
# prior -inf
# theta [[-0.06977456]]
# prior -inf
# theta [[0.39179254]]
# prior 0.10536051565782628
# 1
# theta [[-0.09110845]]
# prior -inf
# theta [[1.07122069]]
# prior -inf
# theta [[0.50865324]]
# prior 0.10536051565782628
# 0.9999332072824144
# theta [[0.63588725]]
# prior 0.10536051565782628
# 0.9985653478916439
# theta [[0.29232361]]
# prior 0.10536051565782628
# 1
# theta [[-0.90532873]]
# prior -inf
# theta [[0.48285254]]
# prior 0.10536051565782628
# 0.999934355711981
# theta [[-0.91833867]]
# prior -inf
# theta [[0.28178613]]
# prior 0.10536051565782628
# 1
# theta [[0.77654331]]
# prior 0.10536051565782628
# 0.9911080686075199
# theta [[0.61274938]]
# prior 0.10536051565782628
# 1
# theta [[-0.01700683]]
# prior -inf
# theta [[0.1293787]]
# prior 0.10536051565782628
# 1
# theta [[-0.73928156]]
# prior -inf
# theta [[0.66572464]]
# prior 0.10536051565782628
# 0.997651162558692
# theta [[0.7401202]]
# prior 0.10536051565782628
# 0.9962412270064511
# theta [[0.36607306]]
# prior 0.10536051565782628
# 1
# theta [[-0.80595816]]
# prior -inf
# theta [[-0.14101762]]
# prior -inf
# theta [[1.08949244]]
# prior -inf
# theta [[-0.14100069]]
# prior -inf
# theta [[-0.67089466]]
# prior -inf
# theta [[0.83218179]]
# prior 0.10536051565782628
# 0.985875903148958
# theta [[1.97877947]]
# prior -inf
# theta [[2.50958508]]
# prior -inf
# theta [[1.1610049]]
# prior -inf
# theta [[0.79958742]]
# prior 0.10536051565782628
# 1
# theta [[2.26745396]]
# prior -inf
# theta [[0.37331065]]
# prior 0.10536051565782628
# 1
# theta [[1.03866502]]
# prior -inf
# theta [[-0.82651109]]
# prior -inf
# theta [[-0.76014828]]
# prior -inf
# theta [[1.12216973]]
# prior -inf
# theta [[1.32197185]]
# prior -inf
# theta [[-1.2626621]]
# prior -inf
# theta [[0.19586702]]
# prior 0.10536051565782628
# 1
# theta [[0.17926026]]
# prior 0.10536051565782628
# 0.999987771135085
# theta [[0.17659493]]
# prior 0.10536051565782628
# 0.9999975274815874
# theta [[-0.55253147]]
# prior -inf
# theta [[1.07664437]]
# prior -inf
# theta [[0.55060159]]
# prior 0.10536051565782628
# 0.9997682663539135
# theta [[-0.12811264]]
# prior -inf
# theta [[1.58134317]]
# prior -inf
# theta [[0.36814598]]
# prior 0.10536051565782628
# 1
# theta [[0.25416502]]
# prior 0.10536051565782628
# 1
# theta [[-0.78988288]]
# prior -inf
# theta [[-0.63480062]]
# prior -inf
# theta [[-0.01698702]]
# prior -inf
# theta [[-0.70382888]]
# prior -inf
# theta [[1.75431499]]
# prior -inf
# theta [[-0.46649265]]
# prior -inf
# theta [[-0.34100309]]
# prior -inf
# theta [[0.87940435]]
# prior 0.10536051565782628
# 0.9803358410095262
# theta [[0.5010467]]
# prior 0.10536051565782628
# 1
# theta [[1.00194896]]
# prior -inf
# theta [[1.00174517]]
# prior -inf
# theta [[0.76801093]]
# prior 0.10536051565782628
# 0.991876170054144
# theta [[1.00271182]]
# prior -inf
# theta [[1.36334198]]
# prior -inf
# theta [[1.70940189]]
# prior -inf
# theta [[1.83564868]]
# prior -inf
# theta [[0.17557015]]
# prior 0.10536051565782628
# 1
# theta [[0.49352405]]
# prior 0.10536051565782628
# 0.9999511438645773
# theta [[1.38909015]]
# prior -inf
# theta [[-0.59986838]]
# prior -inf
# theta [[1.10740471]]
# prior -inf
# theta [[0.37703196]]
# prior 0.10536051565782628
# 1
# theta [[1.73079384]]
# prior -inf
# theta [[-0.815989]]
# prior -inf
# theta [[1.09875654]]
# prior -inf
# theta [[0.6933453]]
# prior 0.10536051565782628
# 0.9964407950122196
# theta [[0.52914081]]
# prior 0.10536051565782628
# 1
# theta [[2.46501392]]
# prior -inf
# theta [[1.20623793]]
# prior -inf
# theta [[0.54566748]]
# prior 0.10536051565782628
# 0.999924256761104
# theta [[2.00584422]]
# prior -inf
# theta [[0.51366433]]
# prior 0.10536051565782628
# 1
# theta [[-1.11394852]]
# prior -inf
# theta [[0.52056613]]
# prior 0.10536051565782628
# 0.9999826502312312
# theta [[0.06200283]]
# prior -inf
# theta [[0.73810487]]
# prior 0.10536051565782628
# 0.9940556047672388
# theta [[0.31411368]]
# prior 0.10536051565782628
# 1
# theta [[0.80799103]]
# prior 0.10536051565782628
# 0.9883144468488635
# theta [[0.81579515]]
# prior 0.10536051565782628
# 0.9992275951604914
# theta [[1.38858704]]
# prior -inf
# theta [[0.41255655]]
# prior 0.10536051565782628
# 1
# theta [[0.19972495]]
# prior 0.10536051565782628
# 1
# theta [[0.44085277]]
# prior 0.10536051565782628
# 0.9999602780144136
# theta [[-0.16862809]]
# prior -inf
# theta [[-0.65055739]]
# prior -inf
# theta [[-0.33906208]]
# prior -inf
# theta [[0.73594082]]
# prior 0.10536051565782628
# 0.9941194399634826
# theta [[0.54464099]]
# prior 0.10536051565782628
# 1
# theta [[-1.11864118]]
# prior -inf
# theta [[1.53287574]]
# prior -inf
# theta [[0.96956458]]
# prior 0.10536051565782628
# 0.9676685071956418
# theta [[0.12594327]]
# prior 0.10536051565782628
# 1
# theta [[-1.063818]]
# prior -inf
# theta [[1.21331953]]
# prior -inf
# theta [[-0.00953592]]
# prior -inf
# theta [[-0.69128375]]
# prior -inf
# theta [[0.64232628]]
# prior 0.10536051565782628
# 0.9984054985897582
# theta [[1.06342566]]
# prior -inf
# theta [[0.19890707]]
# prior 0.10536051565782628
# 1
# theta [[-0.36673676]]
# prior -inf
# theta [[0.43079687]]
# prior 0.10536051565782628
# 0.9999645167528239
# theta [[0.05825997]]
# prior -inf
# theta [[0.28230055]]
# prior 0.10536051565782628
# 1
# theta [[0.66858325]]
# prior 0.10536051565782628
# 0.9974444328548244
# theta [[0.22387749]]
# prior 0.10536051565782628
# 1
# theta [[0.41440726]]
# prior 0.10536051565782628
# 0.9999612980991157
# theta [[0.33661731]]
# prior 0.10536051565782628
# 1
# theta [[-0.07118473]]
# prior -inf
# theta [[1.84925245]]
# prior -inf
# theta [[-0.01867254]]
# prior -inf
# theta [[-0.55422482]]
# prior -inf
# theta [[-0.56418572]]
# prior -inf
# theta [[0.66461476]]
# prior 0.10536051565782628
# 0.9976008897923839
# theta [[0.25249386]]
# prior 0.10536051565782628
# 1
# theta [[-1.01575431]]
# prior -inf
# theta [[-0.03140324]]
# prior -inf
# theta [[0.41494093]]
# prior 0.10536051565782628
# 0.9999580339769268
# theta [[0.12824506]]
# prior 0.10536051565782628
# 0.9999339566006848
# theta [[0.79076285]]
# prior 0.10536051565782628
# 0.9900015026592466
# theta [[0.28752764]]
# prior 0.10536051565782628
# 1
# theta [[0.90243849]]
# prior 0.10536051565782628
# 0.9773201725488861
# theta [[1.88429141]]
# prior -inf
# theta [[1.39124991]]
# prior -inf
# theta [[-0.37051487]]
# prior -inf
# theta [[1.43276582]]
# prior -inf
# theta [[1.35712212]]
# prior -inf
# theta [[0.0497264]]
# prior -inf
# theta [[2.12499169]]
# prior -inf
# theta [[1.0630739]]
# prior -inf
# theta [[0.8887691]]
# prior 0.10536051565782628
# 1
# theta [[0.22425615]]
# prior 0.10536051565782628
# 1
# theta [[-0.36148013]]
# prior -inf
# theta [[-0.80460833]]
# prior -inf
# theta [[0.2676206]]
# prior 0.10536051565782628
# 1
# theta [[-0.57576203]]
# prior -inf
# theta [[-0.12106296]]
# prior -inf
# theta [[-0.30471883]]
# prior -inf
# theta [[-0.72401718]]
# prior -inf
# theta [[0.39089416]]
# prior 0.10536051565782628
# 0.9999674871248359
# theta [[-0.77231043]]
# prior -inf
# theta [[1.60799017]]
# prior -inf
# theta [[1.47174835]]
# prior -inf
# theta [[0.53820169]]
# prior 0.10536051565782628
# 0.999840306000164
# theta [[0.46481699]]
# prior 0.10536051565782628
# 1
# theta [[0.08791862]]
# prior -inf
# theta [[0.21728083]]
# prior 0.10536051565782628
# 1
# theta [[0.705508]]
# prior 0.10536051565782628
# 0.9958244188635733
# theta [[0.85593561]]
# prior 0.10536051565782628
# 0.9873215022608013
# theta [[0.40279133]]
# prior 0.10536051565782628
# 1
# theta [[-0.1584429]]
# prior -inf
# theta [[1.39673767]]
# prior -inf
# theta [[1.13667802]]
# prior -inf
# theta [[0.53333921]]
# prior 0.10536051565782628
# 0.9998658609320813
# theta [[0.39169644]]
# prior 0.10536051565782628
# 1
# theta [[0.44488566]]
# prior 0.10536051565782628
# 0.9999802052174332
# theta [[0.80734477]]
# prior 0.10536051565782628
# 0.9884202850212523
# theta [[-1.08488693]]
# prior -inf
# theta [[1.63783808]]
# prior -inf
# theta [[0.86627198]]
# prior 0.10536051565782628
# 0.9935200730325979
# theta [[1.11850791]]
# prior -inf
# theta [[1.85735404]]
# prior -inf
# theta [[2.21781601]]
# prior -inf
# theta [[0.79097284]]
# prior 0.10536051565782628
# 1
# theta [[1.07375069]]
# prior -inf
# theta [[-1.1174545]]
# prior -inf
# theta [[0.31646666]]
# prior 0.10536051565782628
# 1
# theta [[-0.26553946]]
# prior -inf
# theta [[1.13297313]]
# prior -inf
# theta [[-0.07806908]]
# prior -inf
# theta [[1.11819549]]
# prior -inf
# theta [[0.65641261]]
# prior 0.10536051565782628
# 0.9978747918222156
# theta [[-0.70030026]]
# prior -inf
# theta [[1.86792546]]
# prior -inf
# theta [[1.52870661]]
# prior -inf
# theta [[-0.33405697]]
# prior -inf
# theta [[-0.10509481]]
# prior -inf
# theta [[0.88293725]]
# prior 0.10536051565782628
# 0.9819824513685572
# theta [[1.7842746]]
# prior -inf
# theta [[0.90474982]]
# prior 0.10536051565782628
# 0.99705751749018
# theta [[1.25884418]]
# prior -inf
# theta [[1.2263675]]
# prior -inf
# theta [[0.20288666]]
# prior 0.10536051565782628
# 1
# theta [[0.23514288]]
# prior 0.10536051565782628
# 1
# theta [[-0.01012992]]
# prior -inf
# theta [[1.35650846]]
# prior -inf
# theta [[-0.01978052]]
# prior -inf
# theta [[-0.13215162]]
# prior -inf
# theta [[0.23832359]]
# prior 0.10536051565782628
# 1
# theta [[-0.79427794]]
# prior -inf
# theta [[-0.98692263]]
# prior -inf
# theta [[-0.35760268]]
# prior -inf
# theta [[-0.95751944]]
# prior -inf
# theta [[-0.47873575]]
# prior -inf
# theta [[-0.20312344]]
# prior -inf
# theta [[2.12152673]]
# prior -inf
# theta [[-0.15255858]]
# prior -inf
# theta [[1.48220469]]
# prior -inf
# theta [[-0.05334679]]
# prior -inf
# theta [[-0.66565936]]
# prior -inf
# theta [[-0.2171344]]
# prior -inf
# theta [[-1.06457391]]
# prior -inf
# theta [[-0.46610377]]
# prior -inf
# theta [[0.55827079]]
# prior 0.10536051565782628
# 0.9996872580937051
# theta [[0.4739538]]
# prior 0.10536051565782628
# 1
# theta [[1.27571427]]
# prior -inf
# theta [[0.68589222]]
# prior 0.10536051565782628
# 0.9968115825999885
# theta [[1.65636531]]
# prior -inf
# theta [[0.73600807]]
# prior 0.10536051565782628
# 0.9973079013607904
# theta [[1.01421298]]
# prior -inf
# theta [[1.46459905]]
# prior -inf
# theta [[0.51903221]]
# prior 0.10536051565782628
# 1
# theta [[-0.25802343]]
# prior -inf
# theta [[0.35441058]]
# prior 0.10536051565782628
# 1
# theta [[0.77721614]]
# prior 0.10536051565782628
# 0.991070959726742
# theta [[0.72570739]]
# prior 0.10536051565782628
# 1
# theta [[1.85023769]]
# prior -inf
# theta [[2.03025024]]
# prior -inf
# theta [[1.43033866]]
# prior -inf
# theta [[-0.09916781]]
# prior -inf
# theta [[-0.52455019]]
# prior -inf
# theta [[0.83755996]]
# prior 0.10536051565782628
# 0.9905203155578471
# theta [[2.00905222]]
# prior -inf
# theta [[0.09278426]]
# prior -inf
# theta [[0.96083915]]
# prior 0.10536051565782628
# 0.9832960459288032
# theta [[0.84823726]]
# prior 0.10536051565782628
# 1
# theta [[2.0234652]]
# prior -inf
# theta [[0.5750421]]
# prior 0.10536051565782628
# 1
# theta [[0.85113979]]
# prior 0.10536051565782628
# 0.984206109149538
# theta [[-1.11571198]]
# prior -inf
# theta [[0.82059794]]
# prior 0.10536051565782628
# 1
# theta [[0.90907994]]
# prior 0.10536051565782628
# 0.9892105261647676
# theta [[2.20208937]]
# prior -inf
# theta [[1.47566451]]
# prior -inf
# theta [[-0.9297849]]
# prior -inf
# theta [[1.08432439]]
# prior -inf
# theta [[0.81469247]]
# prior 0.10536051565782628
# 1
# theta [[1.31152042]]
# prior -inf
# theta [[0.76196128]]
# prior 0.10536051565782628
# 1
# theta [[1.86233698]]
# prior -inf
# theta [[0.99824252]]
# prior 0.10536051565782628
# 0.970344079623401
# theta [[-0.11340005]]
# prior -inf
# theta [[-0.20978415]]
# prior -inf
# theta [[2.07943438]]
# prior -inf
# theta [[-0.40868081]]
# prior -inf
# theta [[-0.49754928]]
# prior -inf
# theta [[1.47316912]]
# prior -inf
# theta [[-0.06292755]]
# prior -inf
# theta [[1.36989551]]
# prior -inf
# theta [[1.62849292]]
# prior -inf
# theta [[2.15640793]]
# prior -inf
# theta [[1.00485718]]
# prior -inf
# theta [[0.84318683]]
# prior 0.10536051565782628
# 1
# theta [[1.65390121]]
# prior -inf
# theta [[1.51502584]]
# prior -inf
# theta [[1.68999163]]
# prior -inf
# theta [[0.56311745]]
# prior 0.10536051565782628
# 1
# theta [[0.34719252]]
# prior 0.10536051565782628
# 1
# theta [[1.26700895]]
# prior -inf
# theta [[0.32298243]]
# prior 0.10536051565782628
# 1
# theta [[0.3476192]]
# prior 0.10536051565782628
# 0.9999927485065636
# theta [[-0.34571957]]
# prior -inf
# theta [[0.59135]]
# prior 0.10536051565782628
# 0.9993569888402405
# theta [[1.43157808]]
# prior -inf
# theta [[1.08049956]]
# prior -inf
# theta [[-0.06120374]]
# prior -inf
# theta [[0.59348549]]
# prior 0.10536051565782628
# 0.999969745548567
# theta [[0.50601862]]
# prior 0.10536051565782628
# 1
# theta [[1.20805496]]
# prior -inf
# theta [[-0.5512456]]
# prior -inf
# theta [[0.0876177]]
# prior -inf
# theta [[0.000404]]
# prior -inf
# theta [[1.23510108]]
# prior -inf
# theta [[0.18581794]]
# prior 0.10536051565782628
# 1
# theta [[0.2529186]]
# prior 0.10536051565782628
# 1
# theta [[0.0685116]]
# prior -inf
# theta [[0.10646215]]
# prior 0.10536051565782628
# 0.9998177225208658
# theta [[0.72209142]]
# prior 0.10536051565782628
# 0.995094978611326
# theta [[-0.14011936]]
# prior -inf
# theta [[1.52114062]]
# prior -inf
# theta [[0.83450375]]
# prior 0.10536051565782628
# 0.9906414844101914
# theta [[0.85091711]]
# prior 0.10536051565782628
# 0.9981463185118143
# theta [[0.94943518]]
# prior 0.10536051565782628
# 0.9865675813572619
# theta [[1.01453859]]
# prior -inf
# theta [[1.07549597]]
# prior -inf
# theta [[0.13117987]]
# prior 0.10536051565782628
# 1
# theta [[-0.79288188]]
# prior -inf
# theta [[-0.16085906]]
# prior -inf
# theta [[0.37438258]]
# prior 0.10536051565782628
# 1
# theta [[0.50039551]]
# prior 0.10536051565782628
# 0.9999403895501087
# theta [[0.50253116]]
# prior 0.10536051565782628
# 0.9999969403860437
# theta [[2.11262909]]
# prior -inf
# theta [[-1.00356859]]
# prior -inf
# theta [[1.57630967]]
# prior -inf
# theta [[0.15131968]]
# prior 0.10536051565782628
# 1
# theta [[-1.04779648]]
# prior -inf
# theta [[0.09601451]]
# prior -inf
# theta [[1.12806801]]
# prior -inf
# theta [[-0.02884847]]
# prior -inf
# theta [[0.53574924]]
# prior 0.10536051565782628
# 0.9998798435134026
# theta [[1.74802169]]
# prior -inf
# theta [[-0.60996024]]
# prior -inf
# theta [[0.05190564]]
# prior -inf
# theta [[0.21426633]]
# prior 0.10536051565782628
# 1
# theta [[-0.32747325]]
# prior -inf
# theta [[0.52060066]]
# prior 0.10536051565782628
# 0.9998777604189159
# theta [[-0.76675457]]
# prior -inf
# theta [[0.44409835]]
# prior 0.10536051565782628
# 1
# theta [[2.57565466]]
# prior -inf
# theta [[0.96072421]]
# prior 0.10536051565782628
# 0.9688824659975431
# theta [[1.04129356]]
# prior -inf
# theta [[0.93732193]]
# prior 0.10536051565782628
# 1
# theta [[0.66626473]]
# prior 0.10536051565782628
# 1
# theta [[-0.0297022]]
# prior -inf
# theta [[0.64381048]]
# prior 0.10536051565782628
# 1
# theta [[1.13271529]]
# prior -inf
# theta [[0.29974305]]
# prior 0.10536051565782628
# 1
# theta [[0.2147087]]
# prior 0.10536051565782628
# 0.9999999470490133
# theta [[1.87035051]]
# prior -inf
# theta [[0.7294812]]
# prior 0.10536051565782628
# 0.9944782310890432
# theta [[0.11677715]]
# prior 0.10536051565782628
# 1
# theta [[-0.68561438]]
# prior -inf
# theta [[0.50325477]]
# prior 0.10536051565782628
# 1
# theta [[0.30991629]]
# prior 0.10536051565782628
# 1
# theta [[0.48188409]]
# prior 0.10536051565782628
# 0.9999387677524127
# theta [[-0.33694657]]
# prior -inf
# theta [[-0.6975385]]
# prior -inf
# theta [[1.68383656]]
# prior -inf
# theta [[0.11895967]]
# prior 0.10536051565782628
# 0.9999350076917122
# theta [[0.16823414]]
# prior 0.10536051565782628
# 1
# theta [[0.48046285]]
# prior 0.10536051565782628
# 0.9999694716754729
# theta [[0.18139495]]
# prior 0.10536051565782628
# 1
# theta [[-0.37887901]]
# prior -inf
# theta [[1.48840666]]
# prior -inf
# theta [[-0.34563908]]
# prior -inf
# theta [[-0.11918733]]
# prior -inf
# theta [[0.98314256]]
# prior 0.10536051565782628
# 0.9653113566719549
# theta [[0.71377771]]
# prior 0.10536051565782628
# 1
# theta [[0.89494744]]
# prior 0.10536051565782628
# 0.982859939779911
# theta [[1.22215595]]
# prior -inf
# theta [[0.86799935]]
# prior 0.10536051565782628
# 1
# theta [[0.88991973]]
# prior 0.10536051565782628
# 0.9971786160585829
# theta [[-0.52530702]]
# prior -inf
# theta [[1.20330072]]
# prior -inf
# theta [[0.59148523]]
# prior 0.10536051565782628
# 1
# theta [[2.13107007]]
# prior -inf
# theta [[0.64025907]]
# prior 0.10536051565782628
# 0.9990115826136264
# theta [[-0.79867264]]
# prior -inf
# theta [[-0.73487576]]
# prior -inf
# theta [[-0.78169907]]
# prior -inf
# theta [[0.82809292]]
# prior 0.10536051565782628
# 0.9879157832856857
# theta [[0.06018877]]
# prior -inf
# theta [[0.17389638]]
# prior 0.10536051565782628
# 1
# theta [[0.31427742]]
# prior 0.10536051565782628
# 1
# theta [[0.1052525]]
# prior 0.10536051565782628
# 0.9998209148027456
# theta [[-1.19576525]]
# prior -inf
# theta [[-0.01753927]]
# prior -inf
# theta [[-0.00226191]]
# prior -inf
# theta [[-0.03089267]]
# prior -inf
# theta [[-0.13220026]]
# prior -inf
# theta [[-0.03767606]]
# prior -inf
# theta [[0.31423859]]
# prior 0.10536051565782628
# 1
# theta [[1.60571146]]
# prior -inf
# theta [[-0.54907898]]
# prior -inf
# theta [[0.72828134]]
# prior 0.10536051565782628
# 0.9945547010516516
# theta [[1.85514987]]
# prior -inf
# theta [[0.62927529]]
# prior 0.10536051565782628
# 1
# theta [[2.03111934]]
# prior -inf
# theta [[1.57100079]]
# prior -inf
# theta [[-0.64826744]]
# prior -inf
# theta [[0.65899782]]
# prior 0.10536051565782628
# 0.9991486869308629
# theta [[0.84222921]]
# prior 0.10536051565782628
# 0.9869484281323768
# theta [[0.0659118]]
# prior -inf
# theta [[0.66975233]]
# prior 0.10536051565782628
# 1
# theta [[1.13713297]]
# prior -inf
# theta [[1.23727614]]
# prior -inf
# theta [[1.15275856]]
# prior -inf
# theta [[1.7629357]]
# prior -inf
# theta [[0.99810162]]
# prior 0.10536051565782628
# 0.9653620652137744
# theta [[1.06925801]]
# prior -inf
# theta [[0.95537273]]
# prior 0.10536051565782628
# 1
# theta [[1.38590134]]
# prior -inf
# theta [[1.36423492]]
# prior -inf
# theta [[1.57734508]]
# prior -inf
# theta [[1.43764193]]
# prior -inf
# theta [[3.10425216]]
# prior -inf
# theta [[1.83898727]]
# prior -inf
# theta [[-0.55413987]]
# prior -inf
# theta [[-0.22225277]]
# prior -inf
# theta [[0.97771094]]
# prior 0.10536051565782628
# 0.9963932227431079
# theta [[0.47950924]]
# prior 0.10536051565782628
# 1
# theta [[0.6151695]]
# prior 0.10536051565782628
# 0.9990058688473142
# theta [[0.43593904]]
# prior 0.10536051565782628
# 1
# theta [[0.02317917]]
# prior -inf
# theta [[0.38244757]]
# prior 0.10536051565782628
# 1
# theta [[-0.48913938]]
# prior -inf
# theta [[1.05995916]]
# prior -inf
# theta [[-0.1167454]]
# prior -inf
# theta [[1.69461805]]
# prior -inf
# theta [[-0.45308146]]
# prior -inf
# theta [[-0.3749622]]
# prior -inf
# theta [[-0.09828499]]
# prior -inf
# theta [[-0.7950837]]
# prior -inf
# theta [[1.95698059]]
# prior -inf
# theta [[-0.25795045]]
# prior -inf
# theta [[0.60905888]]
# prior 0.10536051565782628
# 0.9990848426512056
# theta [[1.01982312]]
# prior -inf
# theta [[0.68137454]]
# prior 0.10536051565782628
# 0.9978826109000436
# theta [[0.68686776]]
# prior 0.10536051565782628
# 0.9997644773171204
# theta [[-1.13396261]]
# prior -inf
# theta [[0.11607759]]
# prior 0.10536051565782628
# 1
# theta [[0.22438134]]
# prior 0.10536051565782628
# 1
# theta [[0.67549077]]
# prior 0.10536051565782628
# 0.9971810578647433
# theta [[1.2095787]]
# prior -inf
# theta [[1.05680885]]
# prior -inf
# theta [[0.75876388]]
# prior 0.10536051565782628
# 0.9953014354208638
# theta [[0.70405023]]
# prior 0.10536051565782628
# 1
# theta [[1.50248502]]
# prior -inf
# theta [[0.56549138]]
# prior 0.10536051565782628
# 1
# theta [[-0.06206239]]
# prior -inf
# theta [[0.977582]]
# prior 0.10536051565782628
# 0.9665387106160015
# theta [[0.40927363]]
# prior 0.10536051565782628
# 1
# theta [[-0.63169481]]
# prior -inf
# theta [[1.49824089]]
# prior -inf
# theta [[2.14494921]]
# prior -inf
# theta [[-0.48215756]]
# prior -inf
# theta [[0.37121855]]
# prior 0.10536051565782628
# 1
# theta [[-0.24801396]]
# prior -inf
# theta [[1.41123849]]
# prior -inf
# theta [[0.29600546]]
# prior 0.10536051565782628
# 1
# theta [[0.00687094]]
# prior -inf
# theta [[1.43654343]]
# prior -inf
# theta [[0.1828673]]
# prior 0.10536051565782628
# 0.9999815340834769
# theta [[0.20813006]]
# prior 0.10536051565782628
# 1
# theta [[0.69705919]]
# prior 0.10536051565782628
# 0.9962458678694144
# theta [[1.02081874]]
# prior -inf
# theta [[0.68851092]]
# prior 0.10536051565782628
# 1
# theta [[0.42779054]]
# prior 0.10536051565782628
# 1
# theta [[0.20261456]]
# prior 0.10536051565782628
# 1
# theta [[-0.83464404]]
# prior -inf
# theta [[0.07936651]]
# prior -inf
# theta [[0.63379586]]
# prior 0.10536051565782628
# 0.9985292594810886
# theta [[1.8945605]]
# prior -inf
# theta [[0.31917885]]
# prior 0.10536051565782628
# 1
# theta [[-0.54977719]]
# prior -inf
# theta [[-0.33769938]]
# prior -inf
# theta [[1.99615234]]
# prior -inf
# theta [[0.51645541]]
# prior 0.10536051565782628
# 0.9998930877771637
# theta [[0.59183261]]
# prior 0.10536051565782628
# 0.9994488376668822
# theta [[0.92430717]]
# prior 0.10536051565782628
# 0.9749191161282869
# theta [[0.81033952]]
# prior 0.10536051565782628
# 1
# theta [[0.41184332]]
# prior 0.10536051565782628
# 1
# theta [[2.10515614]]
# prior -inf
# theta [[0.97029249]]
# prior 0.10536051565782628
# 0.967375150321326
# theta [[1.83551418]]
# prior -inf
# theta [[1.18640937]]
# prior -inf
# theta [[1.63606814]]
# prior -inf
# theta [[1.98445243]]
# prior -inf
# theta [[2.45890209]]
# prior -inf
# theta [[1.27247897]]
# prior -inf
# theta [[1.02291008]]
# prior -inf
# theta [[2.04946497]]
# prior -inf
# theta [[1.46098571]]
# prior -inf
# theta [[-0.13900801]]
# prior -inf
# theta [[1.68415569]]
# prior -inf
# theta [[0.79954529]]
# prior 0.10536051565782628
# 1
# theta [[1.11682423]]
# prior -inf
# theta [[0.23145036]]
# prior 0.10536051565782628
# 1
# theta [[0.54251332]]
# prior 0.10536051565782628
# 0.9997875031329406
# theta [[1.816984]]
# prior -inf
# theta [[0.82261835]]
# prior 0.10536051565782628
# 0.9870640483946236
# theta [[1.29727309]]
# prior -inf
# theta [[-1.64123437]]
# prior -inf
# theta [[1.59141425]]
# prior -inf
# theta [[1.75915576]]
# prior -inf
# theta [[1.12848145]]
# prior -inf
# theta [[0.53521471]]
# prior 0.10536051565782628
# 1
# theta [[0.7112265]]
# prior 0.10536051565782628
# 0.9956987918920112
# theta [[0.5189863]]
# prior 0.10536051565782628
# 1
# theta [[-0.15273723]]
# prior -inf
# theta [[0.46330883]]
# prior 0.10536051565782628
# 1
# theta [[0.68803201]]
# prior 0.10536051565782628
# 0.9967133401899473
# theta [[0.6331822]]
# prior 0.10536051565782628
# 1
# theta [[0.56402666]]
# prior 0.10536051565782628
# 1
# theta [[-0.79292996]]
# prior -inf
# theta [[-0.66275053]]
# prior -inf
# theta [[-0.65314546]]
# prior -inf
# theta [[-0.23509196]]
# prior -inf
# theta [[1.04143507]]
# prior -inf
# theta [[0.81279883]]
# prior 0.10536051565782628
# 0.9881936274777271
# theta [[1.96969614]]
# prior -inf
# theta [[0.73114031]]
# prior 0.10536051565782628
# 1
# theta [[1.38624461]]
# prior -inf
# theta [[1.22614511]]
# prior -inf
# theta [[1.08660072]]
# prior -inf
# theta [[1.22198954]]
# prior -inf
# theta [[1.29342141]]
# prior -inf
# theta [[0.23812488]]
# prior 0.10536051565782628
# 1
# theta [[0.03319457]]
# prior -inf
# theta [[0.83145068]]
# prior 0.10536051565782628
# 0.9859303952667403
# theta [[1.58336348]]
# prior -inf
# theta [[0.82575054]]
# prior 0.10536051565782628
# 1
# theta [[0.91763175]]
# prior 0.10536051565782628
# 0.9885328361298364
# theta [[1.55462889]]
# prior -inf
# theta [[1.53582621]]
# prior -inf
# theta [[0.42743005]]
# prior 0.10536051565782628
# 1
# theta [[-0.05089181]]
# prior -inf
# theta [[-0.13471493]]
# prior -inf
# theta [[-0.83998497]]
# prior -inf
# theta [[1.03375364]]
# prior -inf
# theta [[-1.39795522]]
# prior -inf
# theta [[0.50933566]]
# prior 0.10536051565782628
# 0.9999450655163767
# theta [[0.93308286]]
# prior 0.10536051565782628
# 0.9730956800596077
# theta [[1.3087565]]
# prior -inf
# theta [[0.30721825]]
# prior 0.10536051565782628
# 1
# theta [[-0.09203932]]
# prior -inf
# theta [[0.66622652]]
# prior 0.10536051565782628
# 0.9975353282152674
# theta [[0.79908904]]
# prior 0.10536051565782628
# 0.9915943620127989
# theta [[2.05423007]]
# prior -inf
# theta [[1.29507467]]
# prior -inf
# theta [[1.12642077]]
# prior -inf
# theta [[0.53764638]]
# prior 0.10536051565782628
# 1
# theta [[0.259023]]
# prior 0.10536051565782628
# 1
# theta [[0.22180742]]
# prior 0.10536051565782628
# 0.999996557931351
# theta [[0.32160634]]
# prior 0.10536051565782628
# 0.9999927221229212
# theta [[1.27370463]]
# prior -inf
# theta [[1.37087062]]
# prior -inf
# theta [[-0.74915793]]
# prior -inf
# theta [[-2.14295922]]
# prior -inf
# theta [[0.65435563]]
# prior 0.10536051565782628
# 0.9979425643974589
# theta [[0.66460152]]
# prior 0.10536051565782628
# 0.999653840755063
# theta [[0.64836677]]
# prior 0.10536051565782628
# 1
# theta [[0.05412172]]
# prior -inf
# theta [[0.18613175]]
# prior 0.10536051565782628
# 1
# theta [[0.25708136]]
# prior 0.10536051565782628
# 1
# theta [[1.34727278]]
# prior -inf
# theta [[0.8417026]]
# prior 0.10536051565782628
# 0.9848156827276682
# theta [[1.35070449]]
# prior -inf
# theta [[0.48554032]]
# prior 0.10536051565782628
# 1
# theta [[0.20151847]]
# prior 0.10536051565782628
# 1
# theta [[1.49402385]]
# prior -inf
# theta [[0.45665605]]
# prior 0.10536051565782628
# 0.9999533327826247
# theta [[-0.4246873]]
# prior -inf
# theta [[-0.43989782]]
# prior -inf
# theta [[0.76840056]]
# prior 0.10536051565782628
# 0.9918158030805369
# theta [[0.6441718]]
# prior 0.10536051565782628
# 1
# theta [[1.06260055]]
# prior -inf
# theta [[1.1526334]]
# prior -inf
# theta [[0.45993797]]
# prior 0.10536051565782628
# 1
# theta [[-0.37363047]]
# prior -inf
# theta [[-0.99124557]]
# prior -inf
# theta [[-0.33632666]]
# prior -inf
# theta [[1.42159901]]
# prior -inf
# theta [[-0.00443409]]
# prior -inf
# theta [[0.07483166]]
# prior -inf
# theta [[1.2443729]]
# prior -inf
# theta [[0.29092644]]
# prior 0.10536051565782628
# 1
# theta [[-0.06481305]]
# prior -inf
# theta [[-0.60994441]]
# prior -inf
# theta [[1.30537205]]
# prior -inf
# theta [[-0.00236899]]
# prior -inf
# theta [[0.06005204]]
# prior -inf
# theta [[1.5931171]]
# prior -inf
# theta [[1.1964065]]
# prior -inf
# theta [[-0.29204293]]
# prior -inf
# theta [[0.33962825]]
# prior 0.10536051565782628
# 0.9999878325482736
# theta [[0.86258285]]
# prior 0.10536051565782628
# 0.9824232743988925
# theta [[0.60880243]]
# prior 0.10536051565782628
# 1
# theta [[0.40527156]]
# prior 0.10536051565782628
# 1
# theta [[0.81048732]]
# prior 0.10536051565782628
# 0.9881023520466887
# theta [[-0.98446298]]
# prior -inf
# theta [[2.43779466]]
# prior -inf
# theta [[2.34887698]]
# prior -inf
# theta [[2.13444867]]
# prior -inf
# theta [[0.48930585]]
# prior 0.10536051565782628
# 1
# theta [[0.25372709]]
# prior 0.10536051565782628
# 1
# theta [[0.89348067]]
# prior 0.10536051565782628
# 0.978515319607973
# theta [[-0.12867101]]
# prior -inf
# theta [[0.19703338]]
# prior 0.10536051565782628
# 1
# theta [[-0.24081487]]
# prior -inf
# theta [[1.28219681]]
# prior -inf
# theta [[0.31051842]]
# prior 0.10536051565782628
# 1
# theta [[-1.42810726]]
# prior -inf
# theta [[1.01729687]]
# prior -inf
# theta [[0.80982072]]
# prior 0.10536051565782628
# 0.988137027173461
# theta [[-0.37259545]]
# prior -inf
# theta [[-0.19714681]]
# prior -inf
# theta [[-0.24113132]]
# prior -inf
# theta [[0.25473405]]
# prior 0.10536051565782628
# 1
# theta [[0.50126858]]
# prior 0.10536051565782628
# 0.9999118480590647
# theta [[0.9356666]]
# prior 0.10536051565782628
# 0.9727035102557215
# theta [[1.56671348]]
# prior -inf
# theta [[1.76528221]]
# prior -inf
# theta [[0.85600392]]
# prior 0.10536051565782628
# 1
# theta [[1.09771236]]
# prior -inf
# theta [[1.03337437]]
# prior -inf
# theta [[0.82406333]]
# prior 0.10536051565782628
# 1
# theta [[1.12599129]]
# prior -inf
# theta [[0.54334108]]
# prior 0.10536051565782628
# 1
# theta [[0.75148455]]
# prior 0.10536051565782628
# 0.9932370675121239
# theta [[0.56793255]]
# prior 0.10536051565782628
# 1
# theta [[0.43858874]]
# prior 0.10536051565782628
# 1
# theta [[-0.18339811]]
# prior -inf
# theta [[0.66665675]]
# prior 0.10536051565782628
# 0.9975632842055595
# theta [[2.02826946]]
# prior -inf
# theta [[0.18871781]]
# prior 0.10536051565782628
# 1
# theta [[-1.41858764]]
# prior -inf
# theta [[0.00598107]]
# prior -inf
# theta [[1.35882247]]
# prior -inf
# theta [[-0.32403208]]
# prior -inf
# theta [[-1.26224942]]
# prior -inf
# theta [[1.02184544]]
# prior -inf
# theta [[-1.99379262]]
# prior -inf
# theta [[0.23960637]]
# prior 0.10536051565782628
# 1
# theta [[-0.37560333]]
# prior -inf
# theta [[1.0199206]]
# prior -inf
# theta [[0.96139867]]
# prior 0.10536051565782628
# 0.9687271655744838
# theta [[0.99800714]]
# prior 0.10536051565782628
# 0.9939505418449457
# theta [[1.52174567]]
# prior -inf
# theta [[0.31016219]]
# prior 0.10536051565782628
# 1
# theta [[-0.22665882]]
# prior -inf
# theta [[-0.53914184]]
# prior -inf
# theta [[0.59026098]]
# prior 0.10536051565782628
# 0.9993614747189423
# theta [[0.87480674]]
# prior 0.10536051565782628
# 0.9815479931889143
# theta [[1.35533356]]
# prior -inf
# theta [[2.35024724]]
# prior -inf
# theta [[1.34419775]]
# prior -inf
# theta [[0.53347493]]
# prior 0.10536051565782628
# 1
# theta [[0.96074566]]
# prior 0.10536051565782628
# 0.9689946727700217
# theta [[1.65325358]]
# prior -inf
# theta [[0.76887745]]
# prior 0.10536051565782628
# 1
# theta [[1.23810387]]
# prior -inf
# theta [[1.6675185]]
# prior -inf
# theta [[1.01559282]]
# prior -inf
# theta [[2.39662232]]
# prior -inf
# theta [[0.67200339]]
# prior 0.10536051565782628
# 1
# theta [[0.44643455]]
# prior 0.10536051565782628
# 1
# theta [[-0.14451829]]
# prior -inf
# theta [[0.70079687]]
# prior 0.10536051565782628
# 0.9961100099195538
# theta [[2.01264885]]
# prior -inf
# theta [[1.95293809]]
# prior -inf
# theta [[1.00913265]]
# prior -inf
# theta [[-0.08974174]]
# prior -inf
# theta [[0.9618696]]
# prior 0.10536051565782628
# 0.9724886507961144
# theta [[1.28536482]]
# prior -inf
# theta [[0.74607653]]
# prior 0.10536051565782628
# 1
# theta [[0.246933]]
# prior 0.10536051565782628
# 1
# theta [[-0.05150419]]
# prior -inf
# theta [[0.87237639]]
# prior 0.10536051565782628
# 0.9812154886859042
# theta [[0.33466469]]
# prior 0.10536051565782628
# 1
# theta [[0.79847685]]
# prior 0.10536051565782628
# 0.9892139197390867
# theta [[1.56740015]]
# prior -inf
# theta [[-0.00386841]]
# prior -inf
# theta [[0.10524796]]
# prior 0.10536051565782628
# 1
# theta [[-0.26686082]]
# prior -inf
# theta [[0.33447387]]
# prior 0.10536051565782628
# 1
# theta [[0.28523119]]
# prior 0.10536051565782628
# 1
# theta [[0.12856897]]
# prior 0.10536051565782628
# 0.9998956448589911
# theta [[0.51787259]]
# prior 0.10536051565782628
# 0.999986530466929
# theta [[0.1302827]]
# prior 0.10536051565782628
# 1
# theta [[0.3775412]]
# prior 0.10536051565782628
# 1
# theta [[0.71709416]]
# prior 0.10536051565782628
# 0.9952269790395186
# theta [[1.17170593]]
# prior -inf
# theta [[0.79164618]]
# prior 0.10536051565782628
# 0.9945916952268827
# theta [[0.2513341]]
# prior 0.10536051565782628
# 1
# theta [[-0.2816655]]
# prior -inf
# theta [[0.58815924]]
# prior 0.10536051565782628
# 0.9993817923537414
# theta [[1.09016589]]
# prior -inf
# theta [[1.16435037]]
# prior -inf
# theta [[-1.12029102]]
# prior -inf
# theta [[-0.67130494]]
# prior -inf
# theta [[1.41178047]]
# prior -inf
# theta [[1.07191528]]
# prior -inf
# theta [[-0.57326856]]
# prior -inf
# theta [[-0.12260522]]
# prior -inf
# theta [[1.18406422]]
# prior -inf
# theta [[-0.09644618]]
# prior -inf
# theta [[-0.41505881]]
# prior -inf
# theta [[0.22278332]]
# prior 0.10536051565782628
# 1
# theta [[-0.38604689]]
# prior -inf
# theta [[1.50651235]]
# prior -inf
# theta [[0.45532422]]
# prior 0.10536051565782628
# 0.9999461007396274
# theta [[-0.73831059]]
# prior -inf
# theta [[-0.39631453]]
# prior -inf
# theta [[1.06375781]]
# prior -inf
# theta [[-0.55212075]]
# prior -inf
# theta [[0.43152226]]
# prior 0.10536051565782628
# 1
# theta [[0.38281954]]
# prior 0.10536051565782628
# 1
# theta [[0.46483264]]
# prior 0.10536051565782628
# 0.9999694307541329
# theta [[0.87278553]]
# prior 0.10536051565782628
# 0.981224441979801
# theta [[1.12051178]]
# prior -inf
# theta [[1.01760899]]
# prior -inf
# theta [[1.2406319]]
# prior -inf
# theta [[1.93775798]]
# prior -inf
# theta [[0.9372186]]
# prior 0.10536051565782628
# 0.9910557924804901
# theta [[0.75933379]]
# prior 0.10536051565782628
# 1
# theta [[0.99786671]]
# prior 0.10536051565782628
# 0.9702140546753805
# theta [[0.71191579]]
# prior 0.10536051565782628
# 1
# theta [[-0.62835638]]
# prior -inf
# theta [[-1.2291987]]
# prior -inf
# theta [[0.38202275]]
# prior 0.10536051565782628
# 1
# theta [[-0.16046888]]
# prior -inf
# theta [[0.68094277]]
# prior 0.10536051565782628
# 0.9969872100105647
# theta [[0.80455297]]
# prior 0.10536051565782628
# 0.9916506468934586
# theta [[1.22216051]]
# prior -inf
# theta [[0.09409698]]
# prior -inf
# theta [[1.2926081]]
# prior -inf
# theta [[1.35630859]]
# prior -inf
# theta [[0.85920839]]
# prior 0.10536051565782628
# 0.9941088602838918
# theta [[2.01843482]]
# prior -inf
# theta [[1.26475798]]
# prior -inf
# theta [[1.70273907]]
# prior -inf
# theta [[1.21941929]]
# prior -inf
# theta [[0.92990546]]
# prior 0.10536051565782628
# 0.9904872763748437
# theta [[2.25680161]]
# prior -inf
# theta [[1.4524494]]
# prior -inf
# theta [[0.94116694]]
# prior 0.10536051565782628
# 0.9982983241202978
# theta [[1.53646113]]
# prior -inf
# theta [[0.51134672]]
# prior 0.10536051565782628
# 1
# theta [[-0.03664457]]
# prior -inf
# theta [[-0.21897646]]
# prior -inf
# theta [[0.84442115]]
# prior 0.10536051565782628
# 0.9846165476196597
# theta [[1.60132212]]
# prior -inf
# theta [[1.74140142]]
# prior -inf
# theta [[1.16571592]]
# prior -inf
# theta [[-0.54729136]]
# prior -inf
# theta [[0.39067364]]
# prior 0.10536051565782628
# 1
# theta [[0.42034007]]
# prior 0.10536051565782628
# 0.9999891082668998
# theta [[1.83877551]]
# prior -inf
# theta [[-1.88492305]]
# prior -inf
# theta [[-0.38580738]]
# prior -inf
# theta [[0.53645907]]
# prior 0.10536051565782628
# 0.9998590492272099
# theta [[0.77952091]]
# prior 0.10536051565782628
# 0.9910429217036567
# theta [[-0.23412085]]
# prior -inf
# theta [[0.07064088]]
# prior -inf
# theta [[1.44880756]]
# prior -inf
# theta [[-0.09077383]]
# prior -inf
# theta [[-0.16488695]]
# prior -inf
# theta [[1.53379436]]
# prior -inf
# theta [[-0.20329486]]
# prior -inf
# theta [[1.63848747]]
# prior -inf
# theta [[0.49737437]]
# prior 0.10536051565782628
# 1
# theta [[1.23031811]]
# prior -inf
# theta [[-0.4301873]]
# prior -inf
# theta [[1.83981052]]
# prior -inf
# theta [[1.09536592]]
# prior -inf
# theta [[1.07404839]]
# prior -inf
# theta [[0.89858932]]
# prior 0.10536051565782628
# 0.9779168435371828
# theta [[1.05712852]]
# prior -inf
# theta [[0.27449293]]
# prior 0.10536051565782628
# 1
# theta [[0.0704998]]
# prior -inf
# theta [[-0.40993677]]
# prior -inf
# theta [[0.97884192]]
# prior 0.10536051565782628
# 0.9659792816917976
# theta [[-0.28399891]]
# prior -inf
# theta [[0.28479315]]
# prior 0.10536051565782628
# 1
# theta [[0.99862625]]
# prior 0.10536051565782628
# 0.9627670181407811
# theta [[0.69985571]]
# prior 0.10536051565782628
# 1
# theta [[0.89145051]]
# prior 0.10536051565782628
# 0.982612279305853
# theta [[-0.16172412]]
# prior -inf
# theta [[0.35243751]]
# prior 0.10536051565782628
# 1
# theta [[0.44130298]]
# prior 0.10536051565782628
# 0.9999681180777082
# theta [[-0.94851395]]
# prior -inf
# theta [[-0.71692349]]
# prior -inf
# theta [[-0.10618677]]
# prior -inf
# theta [[0.02714347]]
# prior -inf
# theta [[-0.29281894]]
# prior -inf
# theta [[0.16413048]]
# prior 0.10536051565782628
# 1
# theta [[-0.74432658]]
# prior -inf
# theta [[-0.32295019]]
# prior -inf
# theta [[0.73812541]]
# prior 0.10536051565782628
# 0.9939695485142627
# theta [[1.02247636]]
# prior -inf
# theta [[1.10855705]]
# prior -inf
# theta [[1.16963113]]
# prior -inf
# theta [[0.6371904]]
# prior 0.10536051565782628
# 1
# theta [[-0.78105264]]
# prior -inf
# theta [[0.96025067]]
# prior 0.10536051565782628
# 0.9704269365842897
# theta [[0.11084438]]
# prior 0.10536051565782628
# 1
# theta [[0.0728591]]
# prior -inf
# theta [[0.28554348]]
# prior 0.10536051565782628
# 1
# theta [[0.57586112]]
# prior 0.10536051565782628
# 0.999530934442993
# theta [[0.69795503]]
# prior 0.10536051565782628
# 0.9966652494650116
# theta [[0.25280311]]
# prior 0.10536051565782628
# 1
# theta [[1.13612071]]
# prior -inf
# theta [[0.21521716]]
# prior 0.10536051565782628
# 0.9999945434348988
# theta [[0.24717721]]
# prior 0.10536051565782628
# 1
# theta [[1.72010379]]
# prior -inf
# theta [[-0.10426555]]
# prior -inf
# theta [[-1.19015816]]
# prior -inf
# theta [[-0.73975489]]
# prior -inf
# theta [[0.33362666]]
# prior 0.10536051565782628
# 0.9999858805839924
# theta [[-0.15667244]]
# prior -inf
# theta [[1.15351238]]
# prior -inf
# theta [[1.16561138]]
# prior -inf
# theta [[0.90574624]]
# prior 0.10536051565782628
# 0.9768808084854702
# theta [[0.98816651]]
# prior 0.10536051565782628
# 0.9873150032245975
# theta [[1.31574799]]
# prior -inf
# theta [[1.54284006]]
# prior -inf
# theta [[2.17495024]]
# prior -inf
# theta [[1.58583287]]
# prior -inf
# theta [[-0.18021703]]
# prior -inf
# theta [[1.3631102]]
# prior -inf
# theta [[1.62389005]]
# prior -inf
# theta [[0.31554576]]
# prior 0.10536051565782628
# 1
# theta [[1.10547314]]
# prior -inf
# theta [[1.0833187]]
# prior -inf
# theta [[0.48307984]]
# ...
# post -3.7855273512758707e-07
# 1.0
# 1
# theta [[-0.91219421]]
# prior -inf
# theta [[0.54045737]]
# prior 0.10536051565782628
# post -9.634265089916435e-05
# 0.0
# theta [[1.45227416]]
# prior -inf
# theta [[0.78614142]]
# prior 0.10536051565782628
# post -0.00018315087420336107
# 0.0
# theta [[1.1088641]]
# prior -inf
# theta [[0.00041293]]
# prior -inf
# theta [[-0.27950341]]
# prior -inf
# theta [[0.44872188]]
# prior 0.10536051565782628
# post -5.857612739113193e-05
# 1.0
# 0.99994180411879
# theta [[-0.14198503]]
# prior -inf
# theta [[0.0724153]]
# prior -inf
# theta [[-0.58269588]]
# prior -inf
# theta [[1.0237896]]
# prior -inf
# theta [[2.09808847]]
# prior -inf
# theta [[-1.39620555]]
# prior -inf
# theta [[0.61245877]]
# prior 0.10536051565782628
# post -0.00012269474678805648
# 0.0
# theta [[-1.21070426]]
# prior -inf
# theta [[0.49201627]]
# prior 0.10536051565782628
# post -7.503056322406013e-05
# 0.02
# 0.01999967091399081
# theta [[1.07651219]]
# prior -inf
# theta [[0.93122016]]
# prior 0.10536051565782628
# post -0.00022769886442800737
# 0.0
# theta [[0.22832009]]
# prior 0.10536051565782628
# post -2.4342273545309146e-06
# 1.0
# 1
# theta [[0.4154645]]
# prior 0.10536051565782628
# post -4.48926591437426e-05
# 1.0
# 0.9999575424695573
# theta [[0.37421607]]
# prior 0.10536051565782628
# post -2.9367858735001628e-05
# 1.0
# 1
# theta [[-0.49990245]]
# prior -inf
# theta [[1.28270999]]
# prior -inf
# theta [[-0.3401157]]
# prior -inf
# theta [[0.8914023]]
# prior 0.10536051565782628
# post -0.00021562054783241024
# 0.0
# theta [[0.38051475]]
# prior 0.10536051565782628
# post -3.1753044696325064e-05
# 1.0
# 0.9999976148168832
# theta [[0.09237079]]
# prior -inf
# theta [[0.89868067]]
# prior 0.10536051565782628
# post -0.0002196019951439159
# 0.0
# theta [[1.14141737]]
# prior -inf
# theta [[0.17109141]]
# prior 0.10536051565782628
# post -3.5774257810322495e-05
# 1.0
# 0.999995978794971
# theta [[0.19301224]]
# prior 0.10536051565782628
# post -1.6523503603416385e-05
# 1.0
# 1
# theta [[-0.44763307]]
# prior -inf
# theta [[0.26267668]]
# prior 0.10536051565782628
# post -5.851684914997345e-07
# 1.0
# 1
# theta [[0.7296307]]
# prior 0.10536051565782628
# post -0.00016674093793059308
# 0.0
# theta [[-0.4097863]]
# prior -inf
# theta [[1.2393646]]
# prior -inf
# theta [[0.53168085]]
# prior 0.10536051565782628
# post -9.099350232039764e-05
# 0.0
# theta [[-0.3094061]]
# prior -inf
# theta [[-0.69246753]]
# prior -inf
# theta [[-0.2925153]]
# prior -inf
# theta [[-0.28283057]]
# prior -inf
# theta [[0.08231805]]
# prior -inf
# theta [[-0.18271448]]
# prior -inf
# theta [[-0.1281332]]
# prior -inf
# theta [[0.17590248]]
# prior 0.10536051565782628
# post -3.095482022228066e-05
# 1.0
# 0.9999696308094225
# theta [[-0.00368489]]
# prior -inf
# theta [[-0.02688494]]
# prior -inf
# theta [[1.47538735]]
# prior -inf
# theta [[-0.75870613]]
# prior -inf
# theta [[-1.07831974]]
# prior -inf
# theta [[-0.1103741]]
# prior -inf
# theta [[0.1998139]]
# prior 0.10536051565782628
# post -1.2454124256727284e-05
# 1.0
# 1
# theta [[-0.58534146]]
# prior -inf
# theta [[0.17453904]]
# prior 0.10536051565782628
# post -3.226143139266363e-05
# 1.0
# 0.9999801928890275
# theta [[-0.59299489]]
# prior -inf
# theta [[1.31269235]]
# prior -inf
# theta [[-0.00433234]]
# prior -inf
# theta [[-0.22086151]]
# prior -inf
# theta [[-0.86631644]]
# prior -inf
# theta [[1.18356556]]
# prior -inf
# theta [[1.35466161]]
# prior -inf
# theta [[0.29371533]]
# prior 0.10536051565782628
# post -4.984954066235101e-06
# 1.0
# 1
# theta [[-0.43290085]]
# prior -inf
# theta [[0.48965741]]
# prior 0.10536051565782628
# post -7.409856410600893e-05
# 0.03
# 0.029997926663347527
# theta [[0.25623798]]
# prior 0.10536051565782628
# post -3.488113684354472e-07
# 1.0
# 1
# theta [[0.8604306]]
# prior 0.10536051565782628
# post -0.00020626069143478567
# 0.0
# theta [[0.78498967]]
# prior 0.10536051565782628
# post -0.00018275815064415344
# 0.0
# theta [[0.52176225]]
# prior 0.10536051565782628
# post -8.872208386325389e-05
# 0.0
# theta [[-0.81107642]]
# prior -inf
# theta [[-0.33306204]]
# prior -inf
# theta [[0.20026541]]
# prior 0.10536051565782628
# post -1.2212023973346936e-05
# 1.0
# 0.9999881368577628
# theta [[-0.12130174]]
# prior -inf
# theta [[0.01402543]]
# prior -inf
# theta [[-0.10966647]]
# prior -inf
# theta [[1.4133602]]
# prior -inf
# theta [[0.13144478]]
# prior 0.10536051565782628
# post -0.00010821304539079863
# 0.02
# 0.019998080071730668
# theta [[-0.4437794]]
# prior -inf
# theta [[0.01082869]]
# prior -inf
# theta [[1.13935912]]
# prior -inf
# theta [[0.79240172]]
# prior 0.10536051565782628
# post -0.00018509016824472927
# 0.0
# theta [[-0.54931984]]
# prior -inf
# theta [[-0.63750904]]
# prior -inf
# theta [[0.25036198]]
# prior 0.10536051565782628
# post -3.772426091919615e-07
# 1.0
# 1
# theta [[0.73596949]]
# prior 0.10536051565782628
# post -0.00016694397327137378
# 0.0
# theta [[-1.20591079]]
# prior -inf
# theta [[-0.4851526]]
# prior -inf
# theta [[1.6848612]]
# prior -inf
# theta [[1.44303346]]
# prior -inf
# theta [[1.18685152]]
# prior -inf
# theta [[0.50365958]]
# prior 0.10536051565782628
# post -8.033186836542869e-05
# 0.01
# 0.009999200485705297
# theta [[0.4617867]]
# prior 0.10536051565782628
# post -6.341414844443387e-05
# 0.95
# 0.9499401168269013
# theta [[1.13751883]]
# prior -inf
# theta [[1.41734088]]
# prior -inf
# theta [[0.8629817]]
# prior 0.10536051565782628
# post -0.0002070549923782824
# 0.0
# theta [[-0.47491028]]
# prior -inf
# theta [[1.50383249]]
# prior -inf
# theta [[0.36296971]]
# prior 0.10536051565782628
# post -2.517401153439559e-05
# 1.0
# 1
# theta [[0.77756468]]
# prior 0.10536051565782628
# post -0.00018115333740515363
# 0.0
# theta [[1.37800511]]
# prior -inf
# theta [[1.3211777]]
# prior -inf
# theta [[0.92581698]]
# prior 0.10536051565782628
# post -0.00022674117097582565
# 0.0
# theta [[0.25950295]]
# prior 0.10536051565782628
# post -4.1992640893255794e-07
# 1.0
# 1
# theta [[1.42917045]]
# prior -inf
# theta [[-0.34893584]]
# prior -inf
# theta [[0.7594023]]
# prior 0.10536051565782628
# post -0.00017452305630531384
# 0.0
# theta [[-0.31338144]]
# prior -inf
# theta [[-0.55242038]]
# prior -inf
# theta [[-0.01788225]]
# prior -inf
# theta [[1.09894153]]
# prior -inf
# theta [[-0.36870887]]
# prior -inf
# theta [[1.01303326]]
# prior -inf
# theta [[0.55936599]]
# prior 0.10536051565782628
# post -0.00010185546630978228
# 0.0
# theta [[0.99829597]]
# prior 0.10536051565782628
# post -0.0002739717117794116
# 0.0
# theta [[0.21254534]]
# prior 0.10536051565782628
# post -6.666698418057755e-06
# 1.0
# 0.999993753247502
# theta [[1.43834658]]
# prior -inf
# theta [[0.48194952]]
# prior 0.10536051565782628
# post -7.161013370622436e-05
# 0.06
# 0.05999610352040946
# theta [[1.14025933]]
# prior -inf
# theta [[-0.49213241]]
# prior -inf
# theta [[0.80450076]]
# prior 0.10536051565782628
# post -0.0001892056111827886
# 0.0
# theta [[-0.87318556]]
# prior -inf
# theta [[0.76680323]]
# prior 0.10536051565782628
# post -0.00017750666604496152
# 0.0
# theta [[1.41588183]]
# prior -inf
# theta [[0.23135836]]
# prior 0.10536051565782628
# post -1.8774614315367849e-06
# 1.0
# 1
# theta [[-1.01184285]]
# prior -inf
# theta [[-0.59260642]]
# prior -inf
# theta [[-0.48566583]]
# prior -inf
# theta [[-0.60767774]]
# prior -inf
# theta [[1.20600426]]
# prior -inf
# theta [[0.52720765]]
# prior 0.10536051565782628
# post -8.94470339909389e-05
# 0.0
# theta [[1.16146088]]
# prior -inf
# theta [[1.01756548]]
# prior -inf
# theta [[0.53837963]]
# prior 0.10536051565782628
# post -9.539568540778782e-05
# 0.0
# theta [[1.30514787]]
# prior -inf
# theta [[1.64064175]]
# prior -inf
# theta [[-0.44927076]]
# prior -inf
# theta [[-0.01599598]]
# prior -inf
# theta [[0.03263218]]
# prior -inf
# theta [[-0.0877901]]
# prior -inf
# theta [[0.0330849]]
# prior -inf
# theta [[0.98153253]]
# prior 0.10536051565782628
# post -0.00024049419279495768
# 0.0
# theta [[-0.05138889]]
# prior -inf
# theta [[0.10428856]]
# prior 0.10536051565782628
# post -0.00021075289956962517
# 0.0
# theta [[-0.27470948]]
# prior -inf
# theta [[0.64228187]]
# prior 0.10536051565782628
# post -0.00013298915740691378
# 0.0
# theta [[-0.75382906]]
# prior -inf
# theta [[0.95813886]]
# prior 0.10536051565782628
# post -0.00023352779298031949
# 0.0
# theta [[0.32152636]]
# prior 0.10536051565782628
# post -1.1768161902768627e-05
# 1.0
# 0.9999901093484416
# theta [[2.59892159]]
# prior -inf
# theta [[1.18092839]]
# prior -inf
# theta [[-0.67122732]]
# prior -inf
# theta [[-0.58893169]]
# prior -inf
# theta [[-0.01775273]]
# prior -inf
# theta [[0.52642448]]
# prior 0.10536051565782628
# post -8.934455805772602e-05
# 0.0
# theta [[-0.0074218]]
# prior -inf
# theta [[0.51021471]]
# prior 0.10536051565782628
# post -8.307476511051017e-05
# 0.0
# theta [[0.8206724]]
# prior 0.10536051565782628
# post -0.00019739139151216405
# 0.0
# theta [[0.92913696]]
# prior 0.10536051565782628
# post -0.00022757559900302707
# 0.0
# theta [[0.10489316]]
# prior 0.10536051565782628
# post -0.00020753237324494574
# 0.0
# theta [[-0.79795987]]
# prior -inf
# theta [[0.56902869]]
# prior 0.10536051565782628
# post -0.00010765454404421222
# 0.0
# theta [[-0.89439078]]
# prior -inf
# theta [[-0.68841476]]
# prior -inf
# theta [[0.08962055]]
# prior -inf
# theta [[-0.30875235]]
# prior -inf
# theta [[1.5301499]]
# prior -inf
# theta [[0.44862375]]
# prior 0.10536051565782628
# post -5.8539112273152977e-05
# 1.0
# 0.9999532301433735
# theta [[1.37260481]]
# prior -inf
# theta [[1.28790408]]
# prior -inf
# theta [[0.60027926]]
# prior 0.10536051565782628
# post -0.00011897702324182136
# 0.0
# theta [[0.72702153]]
# prior 0.10536051565782628
# post -0.00016520504100194557
# 0.0
# theta [[-1.26631246]]
# prior -inf
# theta [[1.68879585]]
# prior -inf
# theta [[1.05203365]]
# prior -inf
# theta [[0.74063329]]
# prior 0.10536051565782628
# post -0.00016735846226711027
# 0.0
# theta [[0.4961588]]
# prior 0.10536051565782628
# post -7.695177765489336e-05
# 0.01
# 0.009999815875041309
# theta [[1.32400441]]
# prior -inf
# theta [[0.11205169]]
# prior 0.10536051565782628
# post -0.0001729979202389475
# 0.0
# theta [[-1.14083101]]
# prior -inf
# theta [[0.41242318]]
# prior 0.10536051565782628
# post -4.3523401519819526e-05
# 1.0
# 1
# theta [[0.8070427]]
# prior 0.10536051565782628
# post -0.00019028603134354052
# 0.0
# theta [[-0.81972036]]
# prior -inf
# theta [[0.74850865]]
# prior 0.10536051565782628
# post -0.00017125151072988038
# 0.0
# theta [[1.79219588]]
# prior -inf
# theta [[-0.11137179]]
# prior -inf
# theta [[-0.54763696]]
# prior -inf
# theta [[-0.17190852]]
# prior -inf
# theta [[-1.49926359]]
# prior -inf
# theta [[0.07895643]]
# prior -inf
# theta [[0.23759767]]
# prior 0.10536051565782628
# post -9.684997854515171e-07
# 1.0
# 1
# theta [[-0.03496349]]
# prior -inf
# theta [[-0.12814432]]
# prior -inf
# theta [[-0.16326812]]
# prior -inf
# theta [[0.79805713]]
# prior 0.10536051565782628
# post -0.0001874903501660742
# 0.0
# theta [[-0.2282464]]
# prior -inf
# theta [[1.18643899]]
# prior -inf
# theta [[1.08266121]]
# prior -inf
# theta [[0.16225833]]
# prior 0.10536051565782628
# post -4.6822220108776515e-05
# 1.0
# 0.9999541473309425
# theta [[1.47837517]]
# prior -inf
# theta [[-1.075911]]
# prior -inf
# theta [[-1.87091525]]
# prior -inf
# theta [[0.03825657]]
# prior -inf
# theta [[-0.40861854]]
# prior -inf
# theta [[-0.12947077]]
# prior -inf
# theta [[0.96641562]]
# prior 0.10536051565782628
# post -0.0002373687758595603
# 0.0
# theta [[1.38574856]]
# prior -inf
# theta [[-1.30314577]]
# prior -inf
# theta [[-0.23533263]]
# prior -inf
# theta [[1.75464973]]
# prior -inf
# theta [[-0.7528522]]
# prior -inf
# theta [[1.36668537]]
# prior -inf
# theta [[-0.73861338]]
# prior -inf
# theta [[0.85036852]]
# prior 0.10536051565782628
# post -0.00020402833925000423
# 0.0
# theta [[-0.1648407]]
# prior -inf
# theta [[0.54159777]]
# prior 0.10536051565782628
# post -9.669971113068239e-05
# 0.0
# theta [[0.93903039]]
# prior 0.10536051565782628
# post -0.0002308419388152867
# 0.0
# theta [[0.85036256]]
# prior 0.10536051565782628
# post -0.0002040261366063788
# 0.0
# theta [[-0.54338156]]
# prior -inf
# theta [[0.09976695]]
# prior -inf
# theta [[1.68769959]]
# prior -inf
# theta [[0.50439419]]
# prior 0.10536051565782628
# post -8.0695308103906e-05
# 0.01
# 0.00999966127485692
# theta [[0.20109098]]
# prior 0.10536051565782628
# post -1.1775871475797398e-05
# 1.0
# 1
# theta [[-0.223644]]
# prior -inf
# theta [[0.24038855]]
# prior 0.10536051565782628
# post -7.107898759390749e-07
# 1.0
# 1
# theta [[-0.07276347]]
# prior -inf
# theta [[-0.28044459]]
# prior -inf
# theta [[-0.42113816]]
# prior -inf
# theta [[-0.80344571]]
# prior -inf
# theta [[1.59162196]]
# prior -inf
# theta [[-0.60318074]]
# prior -inf
# theta [[0.14037066]]
# prior 0.10536051565782628
# post -8.593079771957024e-05
# 0.27
# 0.2699769915782851
# theta [[-0.90850412]]
# prior -inf
# theta [[-0.4351926]]
# prior -inf
# theta [[-0.17096696]]
# prior -inf
# theta [[-0.68211744]]
# prior -inf
# theta [[-0.51514933]]
# prior -inf
# theta [[0.29512106]]
# prior 0.10536051565782628
# post -5.298794985696292e-06
# 1.0
# 0.9999954120054151
# theta [[1.6447473]]
# prior -inf
# theta [[0.49699196]]
# prior 0.10536051565782628
# post -7.732744400226368e-05
# 0.01
# 0.009999279739449845
# theta [[-0.49749614]]
# prior -inf
# theta [[-0.32669525]]
# prior -inf
# theta [[1.6264032]]
# prior -inf
# theta [[0.57747387]]
# prior 0.10536051565782628
# post -0.00010958686057559828
# 0.0
# theta [[0.41623962]]
# prior 0.10536051565782628
# post -4.5229081532459295e-05
# 1.0
# 0.9999600705106565
# theta [[0.57237911]]
# prior 0.10536051565782628
# post -0.00010843589685537947
# 0.0
# theta [[-1.02052206]]
# prior -inf
# theta [[0.87994476]]
# prior 0.10536051565782628
# post -0.00021116683296601964
# 0.0
# theta [[0.1021444]]
# prior 0.10536051565782628
# post -0.00022219569052623272
# 0.0
# theta [[0.58566502]]
# prior 0.10536051565782628
# post -0.0001123362762398947
# 0.0
# theta [[-1.19370523]]
# prior -inf
# theta [[0.04117117]]
# prior -inf
# theta [[1.16444324]]
# prior -inf
# theta [[1.32793426]]
# prior -inf
# theta [[-0.05700057]]
# prior -inf
# theta [[-0.05142489]]
# prior -inf
# theta [[0.72705859]]
# prior 0.10536051565782628
# post -0.00016523206327001162
# 0.0
# theta [[-2.04087118]]
# prior -inf
# theta [[0.58949447]]
# prior 0.10536051565782628
# post -0.00011345776831260155
# 0.0
# theta [[1.07572288]]
# prior -inf
# theta [[0.46489209]]
# prior 0.10536051565782628
# post -6.477164807726119e-05
# 0.95
# 0.9499814347431894
# theta [[0.86289234]]
# prior 0.10536051565782628
# post -0.00020702625788552797
# 0.0
# theta [[0.82799494]]
# prior 0.10536051565782628
# post -0.00019735967772073848
# 0.0
# theta [[0.39628864]]
# prior 0.10536051565782628
# post -3.770616148997516e-05
# 1.0
# 1
# theta [[0.24112105]]
# prior 0.10536051565782628
# post -6.597211346223022e-07
# 1.0
# 1
# theta [[-0.2289901]]
# prior -inf
# theta [[0.1523305]]
# prior 0.10536051565782628
# post -6.214444233919017e-05
# 0.93
# 0.9299428209671162
# theta [[0.81667084]]
# prior 0.10536051565782628
# post -0.0001947263470379589
# 0.0
# theta [[-0.68645995]]
# prior -inf
# theta [[0.7455099]]
# prior 0.10536051565782628
# post -0.0001699699264778987
# 0.0
# theta [[0.2241662]]
# prior 0.10536051565782628
# post -3.2860244946789927e-06
# 1.0
# 1
# theta [[-0.12639913]]
# prior -inf
# theta [[-0.04509044]]
# prior -inf
# theta [[-0.21371635]]
# prior -inf
# theta [[0.5635804]]
# prior 0.10536051565782628
# post -0.00010452953085474325
# 0.0
# theta [[-0.07976104]]
# prior -inf
# theta [[0.07754031]]
# prior -inf
# theta [[1.92872093]]
# prior -inf
# theta [[-0.56803292]]
# prior -inf
# theta [[-0.70172857]]
# prior -inf
# theta [[0.56115831]]
# prior 0.10536051565782628
# post -0.00010287118939381248
# 0.0
# theta [[-0.03755845]]
# prior -inf
# theta [[-0.01180425]]
# prior -inf
# theta [[-0.45574288]]
# prior -inf
# theta [[0.30054097]]
# prior 0.10536051565782628
# post -6.631658368411894e-06
# 1.0
# 0.9999966543717229
# theta [[2.07805519]]
# prior -inf
# theta [[0.77286362]]
# prior 0.10536051565782628
# post -0.0001791120176434112
# 0.0
# theta [[-0.18055383]]
# prior -inf
# theta [[0.62829561]]
# prior 0.10536051565782628
# post -0.00012896503212159408
# 0.0
# theta [[1.72090825]]
# prior -inf
# theta [[0.50289239]]
# prior 0.10536051565782628
# post -7.99481181021045e-05
# 0.01
# 0.00999926686227853
# theta [[0.13514515]]
# prior 0.10536051565782628
# post -9.853984929366877e-05
# 0.1
# 0.09999080960325037
# theta [[0.06847383]]
# prior -inf
# theta [[-0.6144578]]
# prior -inf
# theta [[2.0322431]]
# prior -inf
# theta [[-1.30021063]]
# prior -inf
# theta [[1.72182293]]
# prior -inf
# theta [[-0.53185938]]
# prior -inf
# theta [[0.43975137]]
# prior 0.10536051565782628
# post -5.440388226526541e-05
# 1.0
# 0.9999522289171776
# theta [[1.25551128]]
# prior -inf
# theta [[0.21860771]]
# prior 0.10536051565782628
# post -4.685989548552636e-06
# 1.0
# 1
# theta [[-0.82699235]]
# prior -inf
# theta [[0.5377685]]
# prior 0.10536051565782628
# post -9.504641703891525e-05
# 0.0
# theta [[-0.74880574]]
# prior -inf
# theta [[0.54729783]]
# prior 0.10536051565782628
# post -9.764380788504681e-05
# 0.0
# theta [[0.05624979]]
# prior -inf
# theta [[0.13774408]]
# prior 0.10536051565782628
# post -9.203363687744105e-05
# 0.12
# 0.11998951874008384
# theta [[0.84390114]]
# prior 0.10536051565782628
# post -0.00020069385181518504
# 0.0
# theta [[0.03168673]]
# prior -inf
# theta [[-0.16880641]]
# prior -inf
# theta [[-0.07218726]]
# prior -inf
# n_acc rate= 0.1605

# %%
cal_f_theta = cal_f.theta.rnd(1000) 
cal_f_p = cal_f.predict(X_std)  
plt.plot(cal_f_theta)
plt.show()
plt.boxplot(cal_f_theta)
plt.show()

cal_f_ml_theta = cal_f_ml.theta.rnd(1000) 
cal_f_ml_p = cal_f_ml.predict(X_std)  
plt.plot(cal_f_ml_theta)
plt.show()
plt.boxplot(cal_f_ml_theta)
plt.show()
